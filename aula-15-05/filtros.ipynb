# %% [markdown]
# <a href="https://colab.research.google.com/github/COMP3025/class-codes/blob/master/aula-15-05/filtros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

import matplotlib.pyplot as plt
from PIL import Image
from numpy import array
import requests
from io import BytesIO

# %%
response = requests.get('https://www.placecage.com/640/360')
img = Image.open(BytesIO(response.content)).convert()
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# transformar a imagem em cinza

# %%
# aplicar o filtro de suavização baseado na média 3x3, 5x5, (2k+1 x 2k+1)
# e plotar as imagens original e suavizada, lado a lado.
